# %%
import torch
import torch.nn as nn
from torchvision.datasets import CIFAR10
import torchvision.transforms as T
import torchvision
import tqdm.notebook as tq
import matplotlib.pyplot as plt
import numpy as np
import pytorchtools as pt
import pytorch_metric_learning.losses as losses
# %matplotlib notebook

# %%
NUM_WORKERS = 8
BATCH_SIZE = 128
INPUT_SIZE = 128
LR = 1e-4
NUM_EPOCHS = 10
DEVICE = "cuda:0"

NORMALIZED_FEATURES = True

# %% [markdown]
# # Model

# %%
model = torchvision.models.resnet18(pretrained=True)
model.fc = nn.Linear(512, 2)
nn.init.xavier_normal_(model.fc.weight)

monitor = pt.ForwardMonitor(model, verbose=False)
monitor.add_layer("fc")

# %% [markdown]
# # Datasets

# %%
# Train loader
tr_train = T.Compose([T.Resize((INPUT_SIZE, INPUT_SIZE)),
                      T.RandomHorizontalFlip(),
                      T.ColorJitter(.1,.1,.1),
                      T.ToTensor()])

data_train = CIFAR10(root=".",train=True,transform=tr_train,download=True)
load_train = torch.utils.data.DataLoader(data_train,
                                         num_workers=NUM_WORKERS,
                                         batch_size=BATCH_SIZE,
                                         shuffle=True,
                                         drop_last=True)
# Out:
# Files already downloaded and verified

# %%
# test loader
tr_test = T.Compose([T.Resize((INPUT_SIZE, INPUT_SIZE)),
                      T.ToTensor()])

data_test = CIFAR10(root=".",train=False,transform=tr_test)
load_test = torch.utils.data.DataLoader(data_test,
                                         num_workers=NUM_WORKERS,
                                         batch_size=BATCH_SIZE,
                                         shuffle=False)

# %% [markdown]
# # Optimization

# %%
optim = torch.optim.Adam(model.parameters(), lr=LR)

# %%
C = 10
Pw = 0.95
minimum_s = np.log((C-1)*Pw/(1-Pw))*(C-1)/C

margin = C/(C-1)

print("scale", minimum_s)
print("margin", margin)
# Out:
# scale 4.6274972008523925
# margin 1.1111111111111112

# %%
criterion = losses.CosFaceLoss(embedding_size=2, margin=margin, scale=minimum_s, num_classes=10)
optim_loss = torch.optim.Adam(criterion.parameters(), lr=1e-3)

# %% [markdown]
# # Training

# %%
from sklearn.metrics import accuracy_score

# %%
def visualize_features(fig, ax, features, labels, normalize=False, title=""):
    ax.clear()
    if normalize:
        norm = np.linalg.norm(features, axis=1)
        features = features / norm.reshape(-1,1)
    scatter = ax.scatter(features[:,0],
                  features[:,1],
                  s = 10,
                  c=labels,
                  cmap="Paired")
    ax.legend(handles=scatter.legend_elements()[0],
                 labels=data_train.classes,
                 loc="upper right",
                fontsize=8)
    
    ax.title.set_text(title)

    fig.canvas.draw()
    fig.canvas.flush_events()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
plt.ion()

n_iter_train = len(load_train)
n_iter_test = len(load_test)
model.to(DEVICE)
criterion.to(DEVICE)

for epoch in range(NUM_EPOCHS):
    model.train()
    criterion.train()
    feature_points = []
    label_values = []
    for iter, (images, labels) in enumerate(tq.tqdm(load_train)):
        optim.zero_grad()
        optim_loss.zero_grad()
        
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)
        
        out = model(images)

        loss = criterion(out, labels)
        loss.backward()

        optim.step()
        optim_loss.step()
        
        if iter % int(.1*n_iter_train) == 0:
            features_val = monitor.get_layer("fc").detach().squeeze(-1).squeeze(-1).cpu().numpy()
            label_values.append(labels.cpu().numpy())
            feature_points.append(features_val)
            
            visualize_features(fig,
                               ax[0],
                               np.vstack(feature_points),
                               np.concatenate(label_values),
                               normalize=NORMALIZED_FEATURES,
                               title="train")

    # test
    features_test = []
    y_pred = []
    y_test = []
    model.eval()
    criterion.eval()
    for iter, (images, labels) in enumerate(tq.tqdm(load_test)):
        images = images.to(DEVICE)
        y_test.append(labels.cpu().numpy())
        with torch.no_grad():
            out = model(images)
            out = criterion.get_logits(out)
        
        y_pred.append(torch.argmax(out, 1).cpu().numpy())
        features = monitor.get_layer("fc").squeeze(-1).squeeze(-1).cpu().numpy()
        features_test.append(features)
            
        if iter % int(0.1*n_iter_test) == 0:
            visualize_features(fig,
                               ax[1],
                               np.vstack(features_test),
                               np.concatenate(y_pred),
                               normalize=NORMALIZED_FEATURES,
                               title="test")
    
    test_acc = accuracy_score(np.concatenate(y_test), np.concatenate(y_pred))
    print(f"Test Accuracy {test_acc*100:.4f}")
# Out:
# <img src="data:image/png;base64,..." width="1000">
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 67.9400
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 77.8000
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 81.0700
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 83.8700
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 84.5700
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 86.3300
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 84.2700
#   0%|          | 0/390 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Test Accuracy 84.7500
#   0%|          | 0/390 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <cell line: 9>()
#      19 labels = labels.to(DEVICE)
#      21 out = model(images)
# ---> 23 loss = criterion(out, labels)
#      24 loss.backward()
#      26 optim.step()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/pytorch_metric_learning/losses/base_metric_loss_function.py:38, in BaseMetricLossFunction.forward(self, embeddings, labels, indices_tuple, ref_emb, ref_labels)
#      36     labels = c_f.to_device(labels, embeddings)
#      37 ref_emb, ref_labels = c_f.set_ref_emb(embeddings, labels, ref_emb, ref_labels)
# ---> 38 loss_dict = self.compute_loss(
#      39     embeddings, labels, indices_tuple, ref_emb, ref_labels
#      40 )
#      41 self.add_embedding_regularization_to_loss_dict(loss_dict, embeddings)
#      42 return self.reducer(loss_dict, embeddings, labels)
#
# File ~/.local/lib/python3.10/site-packages/pytorch_metric_learning/losses/large_margin_softmax_loss.py:107, in LargeMarginSoftmaxLoss.compute_loss(self, embeddings, labels, indices_tuple, ref_emb, ref_labels)
#     105 self.cast_types(dtype, device)
#     106 miner_weights = lmu.convert_to_weights(indices_tuple, labels, dtype=dtype)
# --> 107 mask = self.get_target_mask(embeddings, labels)
#     108 cosine = self.get_cosine(embeddings)
#     109 cosine_of_target_classes = cosine[mask == 1]
#
# KeyboardInterrupt:
